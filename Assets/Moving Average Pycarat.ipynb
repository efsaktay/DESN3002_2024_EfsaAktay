# %%
import pandas as pd 
import plotly.express as px
import pandas_profiling as pp
import yfinance as yf
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "svg"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 import plotly.express as px
# ----> 3 import pandas_profiling as pp
#       4 import yfinance as yf
#       5 import plotly.graph_objects as go
#
# File ~/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas_profiling/__init__.py:7
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# File ~/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas_profiling/controller/pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.__init__ import ProfileReport
#       7 def profile_report(df, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas_profiling/__init__.py:8
#       6 from pandas_profiling.config import Config, config
#       7 from pandas_profiling.controller import pandas_decorator
# ----> 8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#      11 clear_config = ProfileReport.clear_config
#
# File ~/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas_profiling/profile_report.py:11
#       8 from tqdm.auto import tqdm
#      10 from pandas_profiling.config import config
# ---> 11 from pandas_profiling.model.describe import describe as describe_df
#      12 from pandas_profiling.model.messages import MessageType
#      13 from pandas_profiling.report import get_report_structure
#
# File ~/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas_profiling/model/describe.py:11
#       9 from pandas_profiling.config import config as config
#      10 from pandas_profiling.model.base import Variable
# ---> 11 from pandas_profiling.model.correlations import calculate_correlation
#      12 from pandas_profiling.model.sample import Sample, get_sample
#      13 from pandas_profiling.model.summary import (
#      14     get_duplicates,
#      15     get_messages,
#    (...)
#      19     get_table_stats,
#      20 )
#
# File ~/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas_profiling/model/correlations.py:11
#       9 import pandas as pd
#      10 from confuse import NotFoundError
# ---> 11 from pandas.core.base import DataError
#      12 from scipy import stats
#      14 from pandas_profiling.config import config
#
# ImportError: cannot import name 'DataError' from 'pandas.core.base' (/Users/efsaaktay/anaconda3/envs/hku_202324S2/lib/python3.8/site-packages/pandas/core/base.py)

# %%
# Obtaining data 
df = yf.Ticker('AAPL')
# Selecting historical prices period
aapl = df.history(period='20y') # Last 20 years
# See dataframe
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-05-10 00:00:00-04:00    0.397146    0.402135    0.392157    0.397297
# 2004-05-11 00:00:00-04:00    0.399112    0.411055    0.399112    0.410299
# 2004-05-12 00:00:00-04:00    0.405007    0.413322    0.396692    0.412717
# 2004-05-13 00:00:00-04:00    0.409694    0.419067    0.406670    0.411054
# 2004-05-14 00:00:00-04:00    0.411961    0.413020    0.399867    0.409089
# ...                               ...         ...         ...         ...
# 2024-05-02 00:00:00-04:00  172.509995  173.419998  170.889999  173.029999
# 2024-05-03 00:00:00-04:00  186.649994  187.000000  182.660004  183.380005
# 2024-05-06 00:00:00-04:00  182.350006  184.199997  180.419998  181.710007
# 2024-05-07 00:00:00-04:00  183.449997  184.899994  181.320007  182.399994
# 2024-05-08 00:00:00-04:00  182.850006  183.070007  181.449997  182.740005
#
#                               Volume  Dividends  Stock Splits
# Date
# 2004-05-10 00:00:00-04:00  249978400        0.0           0.0
# 2004-05-11 00:00:00-04:00  305172000        0.0           0.0
# 2004-05-12 00:00:00-04:00  245420000        0.0           0.0
# 2004-05-13 00:00:00-04:00  229852000        0.0           0.0
# 2004-05-14 00:00:00-04:00  257801600        0.0           0.0
# ...                              ...        ...           ...
# 2024-05-02 00:00:00-04:00   94214900        0.0           0.0
# 2024-05-03 00:00:00-04:00  163224100        0.0           0.0
# 2024-05-06 00:00:00-04:00   78569700        0.0           0.0
# 2024-05-07 00:00:00-04:00   77305800        0.0           0.0
# 2024-05-08 00:00:00-04:00   45033300        0.0           0.0
#
# [5034 rows x 7 columns]

# %%
# Using Pandas Profiling to generate a report on our dataframe
Profile_1 = pp.ProfileReport(aapl)
Profile_1.to_file("Report1.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Using Pandas Profiling to generate a report on our dataframe
# ----> 2 Profile_1 = pp.ProfileReport(aapl)
#       3 Profile_1.to_file("Report1.html")
#
# AttributeError: module 'pandas' has no attribute 'ProfileReport'
